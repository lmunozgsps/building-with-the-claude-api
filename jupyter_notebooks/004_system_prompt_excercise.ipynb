# %% [markdown]
# # Accesing Claude with the API

# %% [markdown]
# ## System prompts excercise

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text }
    messages.append(assistant_message)

def chat(messages, system = None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.")
answer = chat(messages)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  ## Duplicate Character Checker
#
# Here's a clean Python function that checks a string for duplicate characters:
#
# ```python
# def check_duplicates(text: str) -> dict:
#     """
#     Check a string for duplicate characters.
#
#     Args:
#         text: The string to check for duplicates.
#
#     Returns:
#         A dictionary containing:
#         - 'has_duplicates': Boolean indicating if duplicates exist
#         - 'duplicates': Dictionary of duplicate characters and their counts
#         - 'unique_chars': Set of characters that appear only once
#     """
#     char_count = {}
#
#     for char in text:
#         char_count[char] = char_count.get(char, 0) + 1
#
#     duplicates = {char: count for char, count in char_count.items() if count > 1}
#     unique_chars = {char for char, count in char_count.items() if count == 1}
#
#     return {
#         "has_duplicates": len(duplicates) > 0,
#         "duplicates": duplicates,
#         "unique_chars": unique_chars,
#     }
#
#
# def display_results(text: str) -> None:
#     """Display duplicate check results in a readable format."""
#     print(f"\nAnalyzing: '{text}'")
#     print("-" * 40)
#
#     result = check_duplicates(text)
#
#     if result["has_duplicates"]:
#         print("✗ Duplicates found:")
#         for char, count in sorted(result["duplicates"].items()):
#             display_char = repr(char) if char == " " else char
#             print(f"  '{display_char}' appears {count} times")
#     else:
#         print("✓ No duplicate characters found")
#
#     if result["unique_chars"]:
#         unique_sorted = sorted(result["unique_chars"])
#         print(f"Unique characters: {unique_sorted}")
#
#
# # --- Example Usage ---
# if __name__ == "__main__":
#     test_strings = [
#         "hello world",
#         "abcdef",
#         "Python",
#         "Mississippi",
#         "",
#     ]
#
#     for test in test_strings:
#         display_results(test)
# ```
#
# ### Example Output
#
# ```
# Analyzing: 'hello world'
# ----------------------------------------
# ✗ Duplicates found:
#   'l' appears 3 times
#   'o' appears 2 times
#   ' ' appears 1 times
# Unique characters: ['d', 'e', 'h', 'r', 'w']
#
# Analyzing: 'abcdef'
# ----------------------------------------
# ✓ No duplicate characters found
# Unique characters: ['a', 'b', 'c', 'd', 'e', 'f']
#
# Analyzing: 'Python'
# ----------------------------------------
# ✓ No duplicate characters found
# Unique characters: ['P', 'h', 'n', 'o', 't', 'y']
#
# Analyzing: 'Mississippi'
# ----------------------------------------
# ✗ Duplicates found:
#   'i' appears 4 times
#   'p' appears 2 times
#   's' appears 4 times
# Unique characters: ['M']
# ```
#
# ### Alternative Approaches
#
# ```python
# # Using collections.Counter (concise)
# from collections import Counter
#
# def has_duplicates_counter(text: str) -> bool:
#     return any(count > 1 for count in Counter(text).values())
#
#
# # Using a set (fast simple check)
# def has_duplicates_set(text: str) -> bool:
#     return len(text) != len(set(text))
#
#
# # Case-insensitive check
# def has_duplicates_case_insensitive(text: str) -> bool:
#     text = text.lower()
#     return len(text) != len(set(text))
# ```
#
# ### Key Differences
#
# | Approach | Use Case | Speed |
# |---|---|---|
# | `check_duplicates()` | Full analysis with counts | O(n) |
# | `Counter` | Readable, detailed counts | O(n) |
# | `set` comparison | Simple yes/no check | O(n) |
# | Case-insensitive | Ignore case differences | O(n) |
#
# The **set comparison** approach is

# %%
messages = []

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.")
answer = chat(messages, system = "You are a Python engineer who writes very concise code")
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  ```python
# def has_duplicates(s: str) -> bool:
#     return len(s) != len(set(s))
# ```
#
# **Examples:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' appears twice)
# print(has_duplicates("world"))   # False
# print(has_duplicates("python"))  # False
# print(has_duplicates("programming"))  # True
# ```
#
# If you also want to **identify** which characters are duplicates:
#
# ```python
# def find_duplicates(s: str) -> set:
#     seen = set()
#     return {c for c in s if c in seen or seen.add(c)}
#
# print(find_duplicates("programming"))  # {'g', 'm', 'r'}
# ```
