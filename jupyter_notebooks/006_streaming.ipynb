# %% [markdown]
# # Accesing Claude with the API

# %% [markdown]
# ## Response streaming

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text }
    messages.append(assistant_message)

# %%
messages = []

add_user_message(messages, "Write a one sentence description of a fake database")

stream = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = messages,
    stream = True
)

for event in stream:
    print("Event:", event, "\n")
# Out:
# Event: RawMessageStartEvent(message=Message(id='msg_011CeDPgS1zYFotDL3gUzDnC', container=None, content=[], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=16, output_tokens=1, output_tokens_details=None, server_tool_use=None, service_tier='standard')), type='message_start')
#
# Event: RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
#
# Event: RawContentBlockDeltaEvent(delta=TextDelta(text='Here', type='text_delta'), index=0, type='content_block_delta')
#
# Event: RawContentBlockDeltaEvent(delta=TextDelta(text=' is a one sentence description of a fake database:\n\n**"NovaBase is a fictional cloud-based relational database management system developed by the', type='text_delta'), index=0, type='content_block_delta')
#
# Event: RawContentBlockDeltaEvent(delta=TextDelta(text=' imaginary tech company Syntherion Technologies, designed to store and retrieve data using a propri', type='text_delta'), index=0, type='content_block_delta')
#
# Event: RawContentBlockDeltaEvent(delta=TextDelta(text='etary query language called SynthoSQL."**', type='text_delta'), index=0, type='content_block_delta')
#
# Event: RawContentBlockStopEvent(index=0, type='content_block_stop')
#
# Event: RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=16, output_tokens=64, output_tokens_details=None, server_tool_use=None))
#
# Event: RawMessageStopEvent(type='message_stop')

# %%
messages = []

add_user_message(messages, "Write a one sentence description of a fake database")

with client.messages.stream(
    model = model,
    max_tokens = 1000,
    messages = messages
) as stream:
    for text in stream.text_stream:
        print(text, end = "")
# Out:
# Here is a one sentence description of a fake database:
#
# **"NovaBase is a fictional cloud-based relational database management system developed by the imaginary tech company Synthetix Corp, designed to store and retrieve vast amounts of simulated enterprise data across distributed virtual servers."**

# %%
messages = []

add_user_message(messages, "Write a one sentence description of a fake database")

with client.messages.stream(
    model = model,
    max_tokens = 1000,
    messages = messages
) as stream:
    for text in stream.text_stream:
        pass

stream.get_final_message()
# Out:
# ParsedMessage(id='msg_011CeDQDB5wAb44dZZqJCZYq', container=None, content=[ParsedTextBlock(citations=None, text='Here is a one sentence description of a fake database:\n\n**"NovaBase is a fictional cloud-based relational database management system developed by the imaginary tech company Synthetix Corp, capable of storing and retrieving up to 500 zettabytes of holographic data using quantum-encrypted neural indexing technology."**', type='text', parsed_output=None)], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=16, output_tokens=74, output_tokens_details=None, server_tool_use=None, service_tier='standard'))
