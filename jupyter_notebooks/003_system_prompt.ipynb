# %% [markdown]
# # Accesing Claude with the API

# %% [markdown]
# ## System prompts

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text }
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages
    )
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  ## Solving for x
#
# **Starting equation:**
# 5x + 3 = 2
#
# **Step 1: Subtract 3 from both sides**
#
# 5x + 3 - 3 = 2 - 3
#
# 5x = -1
#
# **Step 2: Divide both sides by 5**
#
# 5x/5 = -1/5
#
# **x = -1/5**
#
# ---
#
# **Check:** Plug x = -1/5 back into the original equation:
#
# 5(-1/5) + 3 = -1 + 3 = **2** ✓

# %%
def chat(messages):
    system = """
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    When the solution is reached, say 'Eureka!'.
    """
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages,
        system = system
    )
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  Let's work through this step by step!
#
# First, let's think about what our goal is. We want to get **x by itself** on one side of the equation.
#
# Right now we have: **5x + 3 = 2**
#
# Let's start with the first step: Can you think of what we should do to **get rid of the +3** on the left side? What operation would help us eliminate it?

# %%
def chat(messages, system = None):

    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages,
        system = system
    )
    return message.content[0].text

messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
When the solution is reached, say 'Eureka!'.
"""

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages, system = system)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  Let's work through this step by step!
#
# First, let's think about what we need to do - we want to get **x by itself** on one side of the equation.
#
# Looking at **5x + 3 = 2**, what do you think should be our first step to start isolating x?
#
# Hint: What could we do to get rid of that **+3** on the left side?

# %%
messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
When the solution is reached, say 'Eureka!'.
"""

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages)
print("Assistant:\n", answer, "\n")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[6], line 11
#       7 When the solution is reached, say 'Eureka!'.
#       8 """
#       9
#      10 add_user_message(messages, "How do I solve 5x+3=2 for x?")
# ---> 11 answer = chat(messages)
#      12 print("Assistant:\n", answer, "\n")
#
# Cell In[5], line 3, in chat(messages, system)
#       1 def chat(messages, system = None):
#       2
# ----> 3     message = client.messages.create(
#       4         model = model,
#       5         max_tokens = 1000,
#       6         messages = messages,
#
# File ~\OneDrive - SPS\Documentos\Git\building-with-the-claude-api\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~\OneDrive - SPS\Documentos\Git\building-with-the-claude-api\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1048, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1041     warnings.warn(
#    1042         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1043         UserWarning,
#    1044         stacklevel=3,
#    1045     )
#    1047 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1048 return self._post(
#    1049     "/v1/messages",
#    1050     body=maybe_transform(
#    1051         {
#    1052             "max_tokens": max_tokens,
#    1053             "messages": messages,
#    1054             "model": model,
#    1055             "cache_control": cache_control,
#    1056             "container": container,
#    1057             "inference_geo": inference_geo,
#    1058             "metadata": metadata,
#    1059             "output_config": output_config,
#    1060             "service_tier": service_tier,
#    1061             "stop_sequences": stop_sequences,
#    1062             "stream": stream,
#    1063             "system": system,
#    1064             "temperature": temperature,
#    1065             "thinking": thinking,
#    1066             "tool_choice": tool_choice,
#    1067             "tools": tools,
#    1068             "top_k": top_k,
#    1069             "top_p": top_p,
#    1070         },
#    1071         message_create_params.MessageCreateParamsStreaming
#    1072         if stream
#    1073         else message_create_params.MessageCreateParamsNonStreaming,
#    1074     ),
#    1075     options=make_request_options(
#    1076         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1077     ),
#    1078     cast_to=Message,
#    1079     stream=stream or False,
#    1080     stream_cls=Stream[RawMessageStreamEvent],
#    1081 )
#
# File ~\OneDrive - SPS\Documentos\Git\building-with-the-claude-api\.venv\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\OneDrive - SPS\Documentos\Git\building-with-the-claude-api\.venv\Lib\site-packages\anthropic\_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'system: Input should be a valid array'}, 'request_id': 'req_011CeDGoxPEqhC5GY1iBfCoW'}

# %%
def chat(messages, system = None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
When the solution is reached, say 'Eureka!'.
"""

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages, system = system)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  Let's work through this step by step!
#
# First, let's think about what our goal is. We want to get **x by itself** on one side of the equation.
#
# Right now we have: **5x + 3 = 2**
#
# There are two things happening to x:
# 1. It's being multiplied by 5
# 2. It's having 3 added to it
#
# A good first step is to deal with the **+3**. What could you do to both sides of the equation to start removing that +3? 🤔
