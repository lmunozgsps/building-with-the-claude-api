# %% [markdown]
# # Accesing Claude with the API

# %% [markdown]
# ## Temperature

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text }
    messages.append(assistant_message)

def chat(messages, system = None, temperature = 1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Generate a one sentence lovecraftian movie idea")
answer = chat(messages, temperature = 0.0)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  **A team of deep-sea researchers discovers that the rhythmic, global phenomenon humans have always called "sleep" is not a biological necessity but a nightly summoning ritual hardwired into our nervous systems by something ancient and vast that has been slowly *eating* our dreaming minds for millennia — and one scientist has just figured out how to stay awake forever.**

# %%
messages = []

add_user_message(messages, "Generate a one sentence lovecraftian movie idea")
answer = chat(messages, temperature = 0.0)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  Here's a Lovecraftian movie idea:
#
# **When a deep-sea mining crew accidentally breaches a submerged obsidian city older than the ocean itself, they begin receiving transmissions in a language that rewires the human brain to perceive a reality so vast and indifferent that survival becomes the least of their concerns.**

# %%
messages = []

add_user_message(messages, "Generate a one sentence lovecraftian movie idea")
answer = chat(messages, temperature = 0.0)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  Here's a Lovecraftian movie idea:
#
# **When a deep-sea mining crew accidentally breaches a submerged obsidian temple older than the ocean itself, they begin receiving transmissions from something vast and patient that has been waiting beneath the pressure and darkness for the last conscious mind on Earth to finally come close enough to hear.**

# %%
messages = []

add_user_message(messages, "Generate a one sentence lovecraftian movie idea")
answer = chat(messages, temperature = 1.0)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  Here's a Lovecraftian movie idea:
#
# **"When a deep-sea mining crew accidentally breaches a submerged obsidian temple older than the ocean itself, they begin receiving transmissions in a language that rewires the human brain to crave the crushing darkness of the abyss — and one by one, they smile and walk into the water."**

# %%
messages = []

add_user_message(messages, "Generate a one sentence lovecraftian movie idea")
answer = chat(messages, temperature = 1.0)
print("Assistant:\n", answer, "\n")
# Out:
# Assistant:
#  **"When a team of deep-sea archaeologists deciphers an ancient sonar frequency emanating from the Mariana Trench, they begin collectively dreaming of a sunken city where a vast, indifferent god has been patiently counting the seconds until humanity remembers how to wake it."**
